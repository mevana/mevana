# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
#Read the data
df=pd.read_csv(r'C:\Users\Dell\Desktop\ProjectsPython\FakeNewsHotair\RAwork_hotair2020_week_0.csv')

#Get shape and head
df.shape
df.head()
# Out:
#    Unnamed: 0  delta_time  recent_fb_counts  recent_tw_counts relatedStories  \
# 0           0        1440                14                 1             []
# 1           1        9266                18                22             []
# 2           2        8964                 1                 1             []
# 3           3        1440                 1                 8             []
# 4           4        1440                 1                 1             []
#
#                                              fb_data  \
# 0  {'total_engagement_count': 7645, 'likes': 6512...
# 1  {'total_engagement_count': 4451, 'likes': 2544...
# 2  {'total_engagement_count': 4267, 'likes': 2086...
# 3  {'total_engagement_count': 3824, 'likes': 2469...
# 4  {'total_engagement_count': 2818, 'likes': 1848...
#
#                                              tw_data  \
# 0  {'tw_count': 22, 'total_count_delta': 1, 'delt...
# 1  {'tw_count': 27, 'total_count_delta': 22, 'del...
# 2  {'tw_count': 2, 'total_count_delta': 1, 'delta...
# 3  {'tw_count': 77, 'total_count_delta': 8, 'delt...
# 4  {'tw_count': 2, 'total_count_delta': 1, 'delta...
#
#                                              li_data  \
# 0  {'li_count': 0, 'total_count_delta': 0, 'delta...
# 1  {'li_count': 0, 'total_count_delta': 0, 'delta...
# 2  {'li_count': 0, 'total_count_delta': 0, 'delta...
# 3  {'li_count': 0, 'total_count_delta': 0, 'delta...
# 4  {'li_count': 0, 'total_count_delta': 0, 'delta...
#
#                                              pi_data  predicted_interactions  \
# 0  {'pi_count': 0, 'delta_period': 1440, 'delta_p...                    7680
# 1  {'pi_count': 3, 'delta_period': 9266, 'delta_p...                    4478
# 2  {'pi_count': 1, 'delta_period': 8964, 'delta_p...                    4269
# 3  {'pi_count': 0, 'delta_period': 1440, 'delta_p...                    3901
# 4  {'pi_count': 1, 'delta_period': 1440, 'delta_p...                    2820
#
#    ...                                             source  \
# 0  ...  {'publisher': 'hotair.com', 'domain': 'hotair....
# 1  ...  {'publisher': 'hotair.com', 'domain': 'hotair....
# 2  ...  {'publisher': 'hotair.com', 'domain': 'hotair....
# 3  ...  {'publisher': 'hotair.com', 'domain': 'hotair....
# 4  ...  {'publisher': 'hotair.com', 'domain': 'hotair....
#
#                                           image_link  has_video  nw_score  \
# 0  https://hotair.com/wp/wp-content/uploads/2020/...      False  0.175000
# 1  https://hotair.com/wp/wp-content/uploads/2018/...      False  0.034965
# 2  https://hotair.com/wp/wp-content/uploads/2019/...      False  0.002008
# 3  https://hotair.com/wp/wp-content/uploads/2019/...      False  0.012500
# 4  https://hotair.com/wp/wp-content/uploads/2020/...      False  0.012500
#
#   max_nw_score                                             topics  \
# 0   573.750657  [{'id': 19, 'name': 'Opinion'}, {'id': 20, 'na...
# 1   302.678968  [{'id': 19, 'name': 'Opinion'}, {'id': 20, 'na...
# 2   702.185625  [{'id': 19, 'name': 'Opinion'}, {'id': 20, 'na...
# 3   201.369770  [{'id': 19, 'name': 'Opinion'}, {'id': 20, 'na...
# 4   297.377881  [{'id': 19, 'name': 'Opinion'}, {'id': 20, 'na...
#
#               authors                     entities  \
# 0    ['Ed Morrissey']           ['Greta Thunberg']
# 1       ['Jazz Shaw']                           []
# 2  ['Karen Townsend']                           []
# 3     ['John Sexton']  ['Trump', 'Warren', 'Iran']
# 4     ['Allahpundit']                           []
#
#                                              article  label
# 0  In case anyone missed this when it aired live ...  REAL
# 1  Back in November, we learned about a mass shoo...  REAL
# 2  Colin Kaepernick has some thoughts about the d...  REAL
# 3  Last night, Elizabeth Warren tweeted a respons...  REAL
# 4  Pitiful. Not the impulse behind the idea � tha...  REAL
#
# [5 rows x 27 columns]

# %%
#DataFlair - Get the labels
labels=df.label
labels.head()
# Out:
# 0    REAL
# 1    REAL
# 2    REAL
# 3    REAL
# 4    REAL
# Name: label, dtype: object

# %%
#DataFlair - Split the dataset
x_train,x_test,y_train,y_test=train_test_split(df['article'], labels, test_size=0.2, random_state=7)

# %%
#DataFlair - Initialize a TfidfVectorizer
tfidf_vectorizer=TfidfVectorizer(stop_words='english', max_df=0.7)

#DataFlair - Fit and transform train set, transform test set
tfidf_train=tfidf_vectorizer.fit_transform(x_train) 
tfidf_test=tfidf_vectorizer.transform(x_test)

# %%
#DataFlair - Initialize a PassiveAggressiveClassifier
pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(tfidf_train,y_train)

#DataFlair - Predict on the test set and calculate accuracy
y_pred=pac.predict(tfidf_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 85.0%

# %%
#DataFlair - Build confusion matrix
confusion_matrix(y_test,y_pred, labels=['FAKE','REAL'])
# Out:
# array([[1, 0],
#        [0, 0]], dtype=int64)
